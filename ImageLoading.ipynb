# %%
ls
# Out:
# 002b950106f7054b5241bc5473f674c1.dcm* 8c224b694bd551af7eed955ed8330bc6.dcm*
# 0193890c0ee458aad077e7fe0acf7185.dcm* 8ce8ce665e02135e8c9264cdefb8e0b5.dcm*
# 036ff5dd423645ac301d071a11f62a79.dcm* 8f5d1065724bb0d5a58d4ca4d11b9619.dcm*
# 05274144af0f6c62e2360abc11ac3c80.dcm* 90af4d0c5c172b68654c187d459f4a98.dcm*
# 0605b1e8f2f329ccdc761d1ff82a993b.dcm* 930892d7c3ecd8bac2c9028841a697ed.dcm*
# 061f0f4c6aef297e273fe2a44a866a97.dcm* 94071562f048ab2de1a06e7c2ac5a231.dcm*
# 0826d404c6c301470859c5fc6c744782.dcm* 9456d238de71d6eb8ab9e5813e994196.dcm*
# 0c7490d8cb7afc6e488e4ab4d8a99c67.dcm* 980be79281297aaa779234631923c850.dcm*
# 0cea5fac0c0d4a930d39c1e38a917f4e.dcm* 982448f43ae1af96c4a2c88add7494b3.dcm*
# 0f2e2f67515077053a6415b69d0b7366.dcm* 9b120537ced018a41c911072d1f8bcbd.dcm*
# 13b3444b10505fa24c93feb0a51aeda9.dcm* 9cdd77b22a03169468361916f73acc95.dcm*
# 1496373bf1578a05180ab504b807e301.dcm* 9e58b517efae97f6ba92ae18675366fa.dcm*
# ...

# %%
cd ./DSB/0a099f2549429d29b32f349e95fb2244/
# Out:
# /Users/Gavin/Documents/R_Coding_Materials/Signal/KaggleBowl/DSB/0a099f2549429d29b32f349e95fb2244

# %%
import dicom
import numpy

test = dicom.read_file('582f3b52e65735f5a77b1040cd6cdb13.dcm')

# %%
test.pixel_array.shape
# Out:
# (512, 512)

# %%
import pylab
pylab.imshow(test.pixel_array, cmap=pylab.cm.bone)
pylab.show()

# %%
import cv2
IMG_PX_SIZE = 150


small = cv2.resize(np.array(test.pixel_array),(IMG_PX_SIZE,IMG_PX_SIZE))

small

#slices.sort(key = lambda x: int(x.ImagePositionPatient[2]))
#       new_slices = []
#      slices = [cv2.resize(np.array(each_slice.pixel_array),(IMG_PX_SIZE,IMG_PX_SIZE))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-ef17426534b8> in <module>()
# ----> 1 import cv2
#       2 IMG_PX_SIZE = 150
#       3
#       4
#       5 small = cv2.resize(np.array(test.pixel_array),(IMG_PX_SIZE,IMG_PX_SIZE))
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-72fbbcfe2587> in <module>()
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'
